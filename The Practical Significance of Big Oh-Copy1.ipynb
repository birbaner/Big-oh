# %%
import random
import time

def selection_sort(arr):
    n = len(arr)
    for i in range(n-1):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]

def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key

def heap_sort(arr):
    def heapify(arr, n, i):
        largest = i
        l = 2 * i + 1
        r = 2 * i + 2

        if l < n and arr[i] < arr[l]:
            largest = l
        if r < n and arr[largest] < arr[r]:
            largest = r

        if largest != i:
            arr[i], arr[largest] = arr[largest], arr[i]
            heapify(arr, n, largest)

    n = len(arr)
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)
    for i in range(n - 1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]
        heapify(arr, i, 0)

def merge_sort(arr):
    def merge(arr, l, m, r):
        n1 = m - l + 1
        n2 = r - m

        L = [0] * n1
        R = [0] * n2

        for i in range(n1):
            L[i] = arr[l + i]
        for j in range(n2):
            R[j] = arr[m + 1 + j]

        i = j = 0
        k = l

        while i < n1 and j < n2:
            if L[i] <= R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1

        while i < n1:
            arr[k] = L[i]
            i += 1
            k += 1

        while j < n2:
            arr[k] = R[j]
            j += 1
            k += 1

    def merge_sort_recursive(arr, l, r):
        if l < r:
            m = (l + r) // 2
            merge_sort_recursive(arr, l, m)
            merge_sort_recursive(arr, m + 1, r)
            merge(arr, l, m, r)

    n = len(arr)
    merge_sort_recursive(arr, 0, n - 1)

def quick_sort(arr):
    def partition(arr, low, high):
        pivot = arr[high]
        i = low - 1

        for j in range(low, high):
            if arr[j] < pivot:
                i += 1
                arr[i], arr[j] = arr[j], arr[i]
        arr[i + 1], arr[high] = arr[high], arr[i + 1]
        return i + 1

    def quick_sort_recursive(arr, low, high):
        if low < high:
            pi = partition(arr, low, high)
            quick_sort_recursive(arr, low, pi - 1)
            quick_sort_recursive(arr, pi + 1, high)

    n = len(arr)
    quick_sort_recursive(arr, 0, n - 1)

# Function to generate a random array of given size
def generate_random_array(size):
    #return [random.randint(1, 1000000) for _ in range(size)]
    return [random.randint(1, size * 10) for _ in range(size)]

# Function to measure the execution time of a sorting procedure
def measure_execution_time(sort_func, arr):
    start_time = time.time()
    sort_func(arr)
    end_time = time.time()
    execution_time = end_time - start_time
    return execution_time

# Sizes of arrays to test
array_sizes = [10, 100, 1000,10000]

# Perform sorting and measure execution time for each size
for size in array_sizes:
    arr = generate_random_array(size)

    # Selection Sort
    execution_time = measure_execution_time(selection_sort, arr.copy())
    print(f"Selection Sort, Size: {size}, Execution Time: {execution_time:.6f} seconds")

    # Insertion Sort
    execution_time = measure_execution_time(insertion_sort, arr.copy())
    print(f"Insertion Sort, Size: {size}, Execution Time: {execution_time:.6f} seconds")

    # Heap Sort
    execution_time = measure_execution_time(heap_sort, arr.copy())
    print(f"Heap Sort, Size: {size}, Execution Time: {execution_time:.6f} seconds")

    # Merge Sort
    execution_time = measure_execution_time(merge_sort, arr.copy())
    print(f"Merge Sort, Size: {size}, Execution Time: {execution_time:.6f} seconds")

    # Quick Sort
    execution_time = measure_execution_time(quick_sort, arr.copy())
    print(f"Quick Sort, Size: {size}, Execution Time: {execution_time:.6f} seconds")

    print()
# Out:
# Selection Sort, Size: 10, Execution Time: 0.000000 seconds
# Insertion Sort, Size: 10, Execution Time: 0.000000 seconds
# Heap Sort, Size: 10, Execution Time: 0.000000 seconds
# Merge Sort, Size: 10, Execution Time: 0.000000 seconds
# Quick Sort, Size: 10, Execution Time: 0.000000 seconds
#
# Selection Sort, Size: 100, Execution Time: 0.000968 seconds
# Insertion Sort, Size: 100, Execution Time: 0.001007 seconds
# Heap Sort, Size: 100, Execution Time: 0.001016 seconds
# Merge Sort, Size: 100, Execution Time: 0.000975 seconds
# Quick Sort, Size: 100, Execution Time: 0.000000 seconds
#
# Selection Sort, Size: 1000, Execution Time: 0.094069 seconds
# Insertion Sort, Size: 1000, Execution Time: 0.111156 seconds
# Heap Sort, Size: 1000, Execution Time: 0.014073 seconds
# Merge Sort, Size: 1000, Execution Time: 0.014377 seconds
# Quick Sort, Size: 1000, Execution Time: 0.004924 seconds
#
# Selection Sort, Size: 10000, Execution Time: 9.537517 seconds
# ...

# %% [markdown]
# # Final one

# %%
import random
import time

def selection_sort(arr):
    n = len(arr)
    for i in range(n-1):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]

def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key

def heapify(arr, n, i):
    largest = i
    l = 2 * i + 1
    r = 2 * i + 2

    if l < n and arr[i] < arr[l]:
        largest = l
    if r < n and arr[largest] < arr[r]:
        largest = r
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        heapify(arr, n, largest)

def heap_sort(arr):
    n = len(arr)
    for i in range(n, -1, -1):
        heapify(arr, n, i)
    for i in range(n-1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]
        heapify(arr, i, 0)

def merge(arr, left, mid, right):
    n1 = mid - left + 1
    n2 = right - mid

    L = [0] * n1
    R = [0] * n2

    for i in range(n1):
        L[i] = arr[left + i]
    for j in range(n2):
        R[j] = arr[mid + 1 + j]

    i = 0
    j = 0
    k = left

    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1

    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1

    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1

def merge_sort(arr, left, right):
    if left < right:
        mid = (left + right) // 2
        merge_sort(arr, left, mid)
        merge_sort(arr, mid+1, right)
        merge(arr, left, mid, right)

def partition(arr, low, high):
    i = low - 1
    pivot = arr[high]

    for j in range(low, high):
        if arr[j] < pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]

    arr[i+1], arr[high] = arr[high], arr[i+1]
    return i + 1

def quick_sort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)
        quick_sort(arr, low, pi - 1)
        quick_sort(arr, pi + 1, high)

def generate_random_array(size):
    return [random.randint(1, 100) for _ in range(size)]

def measure_execution_time(sort_func, arr, *args):
    start_time = time.time()
    sort_func(arr, *args)
    end_time = time.time()
    execution_time = end_time - start_time
    return execution_time

array_sizes = [10, 100, 1000, 10000, 100000, 1000000, 10000000]

for size in array_sizes:
    arr = generate_random_array(size)
    print(f"Array Size: {size}")
    print("-" * 30)
    
    # Selection Sort
    selection_time = measure_execution_time(selection_sort, arr.copy())
    print(f"Selection Sort: {selection_time:.6f} seconds")
    
    # Insertion Sort
    insertion_time = measure_execution_time(insertion_sort, arr.copy())
    print(f"Insertion Sort: {insertion_time:.6f} seconds")
    
    # Heap Sort
    heap_time = measure_execution_time(heap_sort, arr.copy())
    print(f"Heap Sort: {heap_time:.6f} seconds")
    
    # Merge Sort
    merge_time = measure_execution_time(merge_sort, arr.copy(), 0, size-1)
    print(f"Merge Sort: {merge_time:.6f} seconds")
    
    # Quick Sort
    quick_time = measure_execution_time(quick_sort, arr.copy(), 0, size-1)
    print(f"Quick Sort: {quick_time:.6f} seconds")
    
    print("\n")
# Out:
# Array Size: 10
# ------------------------------
# Selection Sort: 0.000000 seconds
# Insertion Sort: 0.000000 seconds
# Heap Sort: 0.000000 seconds
# Merge Sort: 0.000000 seconds
# Quick Sort: 0.000000 seconds
#
#
# Array Size: 100
# ------------------------------
# Selection Sort: 0.002040 seconds
# Insertion Sort: 0.001022 seconds
# Heap Sort: 0.000941 seconds
# Merge Sort: 0.000000 seconds
# Quick Sort: 0.000000 seconds
#
#
# Array Size: 1000
# ------------------------------
# Selection Sort: 0.095598 seconds
# Insertion Sort: 0.107785 seconds
# Heap Sort: 0.013012 seconds
# Merge Sort: 0.011987 seconds
# Quick Sort: 0.005996 seconds
#
#
# Array Size: 10000
# ------------------------------
# Selection Sort: 9.192384 seconds
# Insertion Sort: 11.458350 seconds
# Heap Sort: 0.188159 seconds
# Merge Sort: 0.166476 seconds
# Quick Sort: 0.133106 seconds
#
#
# Array Size: 100000
# ------------------------------

# %%
import random
import time
from heapq import heapify, heappop

# Selection Sort
def selection_sort(arr):
    for i in range(len(arr)):
        min_idx = i
        for j in range(i+1, len(arr)):
            if arr[min_idx] > arr[j]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]

# Insertion Sort
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i-1
        while j >=0 and key < arr[j] :
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key

# Heap Sort
def heap_sort(arr):
    heapify(arr)
    return [heappop(arr) for _ in range(len(arr))]

# Merge Sort
def merge_sort(arr):
    if len(arr) >1:
        mid = len(arr)//2
        L = arr[:mid]
        R = arr[mid:]

        merge_sort(L)
        merge_sort(R)

        i = j = k = 0

        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i+= 1
            else:
                arr[k] = R[j]
                j+= 1
            k+= 1

        while i < len(L):
            arr[k] = L[i]
            i+= 1
            k+= 1

        while j < len(R):
            arr[k] = R[j]
            j+= 1
            k+= 1

# Quick Sort
def partition(arr, low, high):
    i = (low-1)
    pivot = arr[high]

    for j in range(low, high):
        if arr[j] <= pivot:
            i = i+1
            arr[i], arr[j] = arr[j], arr[i]
    arr[i+1], arr[high] = arr[high], arr[i+1]
    return (i+1)

def quick_sort(arr, low, high):
    if len(arr) == 1:
        return arr
    if low < high:
        pi = partition(arr, low, high)
        quick_sort(arr, low, pi-1)
        quick_sort(arr, pi+1, high)

# Testing
sizes = [10, 100, 1000, 10000, 100000, 1000000, 10000000]

for size in sizes:
    arr = [random.randint(0, size) for _ in range(size)]

    start_time = time.time()
    selection_sort(list(arr))
    print(f"Selection sort time for size {size}: {time.time() - start_time}")

    start_time = time.time()
    insertion_sort(list(arr))
    print(f"Insertion sort time for size {size}: {time.time() - start_time}")

    start_time = time.time()
    heap_sort(list(arr))
    print(f"Heap sort time for size {size}: {time.time() - start_time}")

    start_time = time.time()
    merge_sort(list(arr))
    print(f"Merge sort time for size {size}: {time.time() - start_time}")

    start_time = time.time()
    quick_sort(list(arr), 0, len(arr)-1)
    print(f"Quick sort time for size {size}: {time.time() - start_time}")
# Out:
# Selection sort time for size 10: 0.0
# Insertion sort time for size 10: 0.0
# Heap sort time for size 10: 0.0
# Merge sort time for size 10: 0.0
# Quick sort time for size 10: 0.0
# Selection sort time for size 100: 0.0
# Insertion sort time for size 100: 0.001171112060546875
# Heap sort time for size 100: 0.0
# Merge sort time for size 100: 0.0
# Quick sort time for size 100: 0.0
# Selection sort time for size 1000: 0.04270005226135254
# Insertion sort time for size 1000: 0.04696917533874512
# Heap sort time for size 1000: 0.0
# Merge sort time for size 1000: 0.007036924362182617
# Quick sort time for size 1000: 0.002627849578857422
# Selection sort time for size 10000: 5.391779184341431
# Insertion sort time for size 10000: 6.23897123336792
# Heap sort time for size 10000: 0.00899648666381836
# Merge sort time for size 10000: 0.0816962718963623
# Quick sort time for size 10000: 0.046991825103759766

# %%
pip cache purge
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: No matching packages
